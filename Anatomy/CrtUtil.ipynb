# %%
from google.colab import drive
drive.mount('/content/drive/')
DIR='/content/drive/MyDrive/Research/OntoConnectWithGNN/GNN_1/Anatomy/'
# Out:
# Mounted at /content/drive/

# %% [markdown]
# <h3>
#   <b>
#     Creating constant file (OntoSimConstants.py)
#   </b>
# </h3>

# %%
# %%writefile /content/drive/MyDrive/Research/OntoConnectWithGNN/GNN_1/Anatomy/OntoSimConstants.py

#constants
# DIR='/content/drive/MyDrive/Research/OntoConnectWithGNN/GNN_1/Anatomy/'
# DIR='/home/jchakra1/gnn_1/'
DIR=''
DATA_DIR=DIR+"data/"
code_path=""
wait_time=15

frm_vic_1="model"
frm_vic_2="vec-fl"
faxt_text_model_path='/content/drive/MyDrive/OntoConn/FastText/300d/'
vec_nm=""

join_str_cnst="-#-"

top_k=5
word_sim_ind_1="cosine"
word_sim_ind_2="euclidean"

ds_nm_1="Anatomy"
ds_nm_2="LargeBio"

data_param_json="ontosim.json"
# Out:
# Overwriting /content/drive/MyDrive/Research/OntoConnectWithGNN/GNN_1/OntoSimConstants.py

# %% [markdown]
# <h3>
#   <b>
#     Creating import file (OntoSimImports.py)
#   </b>
# </h3>

# %%
# %%writefile /content/drive/MyDrive/Research/OntoConnectWithGNN/GNN_1/Anatomy/OntoSimImports.py

#imports
import nltk
nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer

import re
import os

import copy

import time
import datetime
import traceback

import json
import numpy as np

import scipy.spatial.distance

import numpy as np
from collections import OrderedDict

import shutil
import h5py
from pathlib import Path

import math
import statistics

import xml.etree.ElementTree as ET

import fasttext
import fasttext.util
from fasttext import load_model

from torchbiggraph.config import parse_config
from torchbiggraph.converters.importers import TSVEdgelistReader, convert_input_data
from torchbiggraph.train import train
from torchbiggraph.util import SubprocessInitializer, setup_logging
# Out:
# Overwriting /content/drive/MyDrive/Research/OntoConnectWithGNN/GNN_1/OntoSimImports.py

# %% [markdown]
# <h3>
#   <b>
#     Creating data_param file (ontosim.json)
#   </b>
# </h3>

# %%
import json
s = {
  "db" : {
    "db_nm" : "Anatomy",
    "vec_dim": 300,
    "op_k": 0,
    "word_wt_ds": 0,
    "meta_wt_ds": 0,
    "threshold_ds": 0,
    "sim_ind": "cosine", #euclidean
  },
  "model" : {
    "vec_dim": 300,
    "learning_rate": 0.01,
    "init_epoch": 1,
    "total_epoch": 100,
    "prev_embed": 1,
    "save_intermediate_node": 20
  }
}

fl= '/content/drive/MyDrive/Research/OntoConnectWithGNN/GNN_1/Anatomy/ontosim.json'
with open(fl, "w") as write_file:
    json.dump(s, write_file, ensure_ascii=True, indent=4, sort_keys=True)

# %% [markdown]
# <h3>
#   <b>
#     Creating all the folders under data folder
#   </b>
# </h3>

# %%
DATA_DIR=DIR+"data/"
fl_path=DATA_DIR+'modifylbl'
os.makedirs(fl_path, exist_ok=True)
fl_path=DATA_DIR+'util'
os.makedirs(fl_path, exist_ok=True)
fl_path=DATA_DIR+'dict'
os.makedirs(fl_path, exist_ok=True)
fl_path=DATA_DIR+'fastentity'
os.makedirs(fl_path, exist_ok=True)
fl_path=DATA_DIR+'gnnentity/'
os.makedirs(fl_path, exist_ok=True)
fl_path=DATA_DIR+'gnnentity/entity_graph/'
os.makedirs(fl_path, exist_ok=True)
fl_path=DATA_DIR+'output/word_sim/'
os.makedirs(fl_path, exist_ok=True)
fl_path=DATA_DIR+'output/meta_sim/'
os.makedirs(fl_path, exist_ok=True)
fl_path=DATA_DIR+'result/'
os.makedirs(fl_path, exist_ok=True)


# #create once
# fl_path=DATA_DIR+'gold_copy/'
# os.makedirs(fl_path, exist_ok=True)
# fl_path=DATA_DIR+'ip/'
# os.makedirs(fl_path, exist_ok=True)

# %%
# !cp -r /content/drive/MyDrive/Research/OntoConnectWithGNN/GNN_1/Anatomy/data /content/drive/MyDrive/Research/OntoConnectWithGNN/GNN_1/Anatomy/data_100

# %%
# !cp -r /content/drive/MyDrive/Research/OntoConnectWithGNN/GNN_1/Anatomy/ /content/drive/MyDrive/Research/OntoConnectWithGNN/GNN_1/Library/
